# %%
import tensorflow as tf

# %%
import numpy as np

# %%
y=1
print(y)
# Out:
# 1

# %%
filename = '/content/birds.jpg'

# %%
from IPython.display import Image
Image(filename,width=224,height=224)

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename,target_size=(224,224))

# %%
print img
# Out:
#   File "<ipython-input-23-14e75ea99dd1>", line 1
#     print img
#             ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(img)?

# %%
print(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F6B53A79310>

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
model = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
resizedimg = image.img_to_array(img)

# %%
finalimg = np.expand_dims(resizedimg,axis=0)

# %%
finalimg = tensorflow.keras.applications.mobilenet_v2.preprocess_input(finalimg)

# %%
finalimg.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = model.predict(finalimg)

# %%
from tensoflow.keras.applications import imagenet_utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-686867ec3fe9> in <module>()
# ----> 1 from tensoflow.keras.applications import imagenet_utils
#
# ModuleNotFoundError: No module named 'tensoflow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n01531178', 'goldfinch', 0.27814022), ('n01819313', 'sulphur-crested_cockatoo', 0.12517999), ('n01818515', 'macaw', 0.09375458), ('n01580077', 'jay', 0.036273383), ('n01817953', 'African_grey', 0.033825345)]]
